# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/sobel_2.jpg")  
sobel_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)
magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
magnitude = np.uint8(magnitude)
plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.title("Sobel X (Horizontal Gradient)")
plt.imshow(sobel_x, cmap='gray')
plt.subplot(1,3,2)
plt.title("Sobel Y (Vertical Gradient)")
plt.imshow(sobel_y, cmap='gray')
plt.subplot(1,3,3)
plt.title("Gradient Magnitude")
plt.imshow(magnitude, cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1020.0..1020.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1020.0..1020.0].

# %%
img = cv2.imread("images/sobel_1.png")  
sobel_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)
magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
magnitude = np.uint8(magnitude)
plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.title("Sobel X (Horizontal Gradient)")
plt.imshow(sobel_x, cmap='gray')
plt.subplot(1,3,2)
plt.title("Sobel Y (Vertical Gradient)")
plt.imshow(sobel_y, cmap='gray')
plt.subplot(1,3,3)
plt.title("Gradient Magnitude")
plt.imshow(magnitude, cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1020.0..1020.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1020.0..1020.0].
