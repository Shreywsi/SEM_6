# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("images/Canny_1.jpg")
img = cv2.GaussianBlur(img, (5,5), 0)
edges1 = cv2.Canny(img, 50, 100)    
edges2 = cv2.Canny(img, 100, 200)   
edges3 = cv2.Canny(img, 150, 250)   
plt.figure(figsize=(25,15))
plt.subplot(131)
plt.imshow(edges1, cmap='gray')
plt.title("50-100")
plt.axis('off')

plt.subplot(132)
plt.imshow(edges2, cmap='gray')
plt.title("100-200")
plt.axis('off')

plt.subplot(133)
plt.imshow(edges3, cmap='gray')
plt.title("150-250")
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("images/canny_2.jpg")
img = cv2.GaussianBlur(img, (5,5), 0)
edges1 = cv2.Canny(img, 50, 100)    
edges2 = cv2.Canny(img, 100, 200)   
edges3 = cv2.Canny(img, 150, 250)   
plt.figure(figsize=(25,15))
plt.subplot(131)
plt.imshow(edges1, cmap='gray')
plt.title("10-50")
plt.axis('off')

plt.subplot(132)
plt.imshow(edges2, cmap='gray')
plt.title("100-200")
plt.axis('off')

plt.subplot(133)
plt.imshow(edges3, cmap='gray')
plt.title("200-300")
plt.axis('off')

plt.show()
