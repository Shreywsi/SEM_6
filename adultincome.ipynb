# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("adult.csv").replace(" ?", pd.NA).dropna()

for c in df.select_dtypes(include='object'):
    df[c] = LabelEncoder().fit_transform(df[c])

X = StandardScaler().fit_transform(df.drop("income", axis=1))
y = df["income"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = Sequential([Dense(32,'relu',input_shape=(X_train.shape[1],)),
                    Dense(16,'relu'),
                    Dense(1,'sigmoid')])

model.compile('adam','binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10,batch_size=32)

print(model.evaluate(X_test,y_test))
# Out:
# Epoch 1/10
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step - accuracy: 0.8254 - loss: 0.3724
# Epoch 2/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 538us/step - accuracy: 0.8476 - loss: 0.3280
# Epoch 3/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step - accuracy: 0.8488 - loss: 0.3232
# Epoch 4/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 581us/step - accuracy: 0.8523 - loss: 0.3203
# Epoch 5/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 580us/step - accuracy: 0.8503 - loss: 0.3189
# Epoch 6/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 565us/step - accuracy: 0.8519 - loss: 0.3172
# Epoch 7/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step - accuracy: 0.8542 - loss: 0.3158
# Epoch 8/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 537us/step - accuracy: 0.8527 - loss: 0.3150
# Epoch 9/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 542us/step - accuracy: 0.8540 - loss: 0.3139
# Epoch 10/10
# 1069/1069 ━━━━━━━━━━━━━━━━━━━━ 1s 537us/step - accuracy: 0.8543 - loss: 0.3133
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.8510 - loss: 0.3202
# [0.3201866149902344, 0.8510202765464783]
