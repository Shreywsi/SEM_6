# %%
import pandas as pd
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
datasets = {
    "Iris": load_iris(),
    "Wine": load_wine(),
    "Breast Cancer": load_breast_cancer()
}

# %%
algorithms = {
    "ID3": {"criterion": "entropy"},
    "C4.5": {"criterion": "entropy", "splitter": "best"},  
    "CART": {"criterion": "gini"}
}

# %%
def evaluate(y_true, y_pred):
    return {
        "Accuracy": round(accuracy_score(y_true, y_pred), 3),
        "Precision": round(precision_score(y_true, y_pred, average='weighted'), 3),
        "Recall": round(recall_score(y_true, y_pred, average='weighted'), 3),
        "F1-Score": round(f1_score(y_true, y_pred, average='weighted'), 3)
    }

# %%
results = []

for ds_name, ds in datasets.items():
    X_train, X_test, y_train, y_test = train_test_split(ds.data, ds.target, test_size=0.3, random_state=42)
    
    for algo_name, params in algorithms.items():
        clf = DecisionTreeClassifier(**params, random_state=42)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        metrics = evaluate(y_test, y_pred)
        results.append({"Dataset": ds_name, "Algorithm": algo_name, **metrics})

# %%
df = pd.DataFrame(results)
print(df.pivot(index="Dataset", columns="Algorithm")[["Accuracy","Precision","Recall","F1-Score"]])
# Out:
#               Accuracy               Precision               Recall         \
# Algorithm         C4.5   CART    ID3      C4.5   CART    ID3   C4.5   CART
# Dataset
# Breast Cancer    0.965  0.942  0.965     0.965  0.943  0.965  0.965  0.942
# Iris             0.978  1.000  0.978     0.979  1.000  0.979  0.978  1.000
# Wine             0.852  0.963  0.852     0.855  0.964  0.855  0.852  0.963
#
#                      F1-Score
# Algorithm        ID3     C4.5   CART    ID3
# Dataset
# Breast Cancer  0.965    0.965  0.942  0.965
# Iris           0.978    0.978  1.000  0.978
# Wine           0.852    0.851  0.963  0.851
