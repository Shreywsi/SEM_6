# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("indian_liver_patient.csv")
df["Albumin_and_Globulin_Ratio"] = df["Albumin_and_Globulin_Ratio"].fillna(df["Albumin_and_Globulin_Ratio"].mean())
df["Gender"] = LabelEncoder().fit_transform(df["Gender"])

X = StandardScaler().fit_transform(df.drop("Dataset", axis=1))
y = df["Dataset"].replace({2:0})

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = Sequential([Dense(32,'relu',input_shape=(X_train.shape[1],)),
                    Dense(16,'relu'),
                    Dense(1,'sigmoid')])

model.compile('adam','binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10,batch_size=32)

print(model.evaluate(X_test,y_test))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4142 - loss: 0.7649
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5735 - loss: 0.6849
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6348 - loss: 0.6397
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6814 - loss: 0.6130
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7034 - loss: 0.5932
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7083 - loss: 0.5787
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7108 - loss: 0.5655
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7108 - loss: 0.5539
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7157 - loss: 0.5435
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7181 - loss: 0.5340
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7257 - loss: 0.5535
# [0.5535355806350708, 0.7257142663002014]
